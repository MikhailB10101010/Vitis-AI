# %% [markdown]
# # 1

# %%
import sqlite3
import pandas as pd
from pathlib import Path

current_path = Path.cwd()
db_folder_path = current_path.resolve().parent / "data"

db_name = "vineyard_1.db"
db_path = db_folder_path / db_name

if db_path.is_file():  # Проверяет, что это файл, а не папка
    print("Файл существует")
else:
    print("! Файл не существует !")
# Out:
# Файл существует

# %%
conn = sqlite3.connect(db_path)
df_columns = pd.read_sql_query("PRAGMA table_info(vineyard_features)", conn)
display(df_columns)
conn.close()
# Out:
#     cid                           name       type  notnull         dflt_value  \
# 0     0                         osm_id    INTEGER        0                NaN
# 1     1                            lat       REAL        1                NaN
# 2     2                            lon       REAL        1                NaN
# 3     3                     created_at  TIMESTAMP        0  CURRENT_TIMESTAMP
# 4     4                     updated_at  TIMESTAMP        0                NaN
# 5     5         elevation_GEE_USGS_30m       REAL        0                NaN
# 6     6  elevation_GEE_USGS_30m_status       TEXT        0          'pending'
# 7     7             slope_GEE_USGS_30m       REAL        0                NaN
# 8     8      slope_GEE_USGS_30m_status       TEXT        0          'pending'
# 9     9            aspect_GEE_USGS_30m       REAL        0                NaN
# 10   10     aspect_GEE_USGS_30m_status       TEXT        0          'pending'
# ...

# %% [markdown]
# # Переименование столбцов

# %%
conn = sqlite3.connect(db_path)
cursor = conn.cursor()

table_name = "vineyard_features"
column_old = "elevation_status"
column_new = "elevation_GEE_USGS_30m_status"

try:
    query = f'''
        ALTER TABLE {table_name} 
        RENAME COLUMN {column_old} TO {column_new}
    '''

    cursor.execute(query)
    conn.commit()
    print("Столбец успешно переименован!")
except sqlite3.Error as e:
    print(f"Ошибка (возможно, столбца нет или версия SQLite старая): {e}")

conn.close()
# Out:
# Столбец успешно переименован!

# %% [markdown]
# # Тесты

# %%
from repository import get_pending

ans = get_pending(db_path, "elevation_GEE_USGS_30m", limit=999)

print('len = ', len(ans))
print(ans, end='\n\n')

if isinstance(ans, list):
    for i in ans:
        print(i)
# Out:
# len =  999
# ...

# %%
osm_ids, *coords_parts = zip(*ans)
osm_id = list(osm_ids)
coords = list(zip(*coords_parts))

print(f"{osm_id = }")
print(f"{coords = }")

osm_id = [item[0] for item in ans]
coords = [list(item[1:]) for item in ans]

print(f"{osm_id = }")
print(f"{coords = }")
# Out:
# osm_id = [4812832, 5070441, 5366540, 8055868, 8076023]
# coords = [(47.69637551006305, 8.639512053255235), (48.81493095443544, 9.447629311916069), (48.81969093242926, 9.181872018296247), (50.3659635590912, 8.729747817763938), (50.150772891815535, 8.730585255314155)]
# osm_id = [4812832, 5070441, 5366540, 8055868, 8076023]
# coords = [[47.69637551006305, 8.639512053255235], [48.81493095443544, 9.447629311916069], [48.81969093242926, 9.181872018296247], [50.3659635590912, 8.729747817763938], [50.150772891815535, 8.730585255314155]]
