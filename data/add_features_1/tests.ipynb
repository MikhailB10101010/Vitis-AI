# %%
import os
from dotenv import load_dotenv, find_dotenv
load_dotenv(find_dotenv())
# Out:
# True

# %% [markdown]
# # elevation

# %%
import ee

# Trigger the authentication flow.
ee.Authenticate()

# Initialize the library.
ee.Initialize(project=os.getenv('GEE_PROJECT_ID'))

# %% [markdown]
# ## `terrain_GEE_USGS.py`
# 'elevation', 'slope', 'aspect', 'hillshade'

# %%
from services.terrain_GEE_USGS import terrain_GEE_USGS

# Текст одной позиции через Lat, Lon

lat = 56.728766
lon = 60.587326

ans = terrain_GEE_USGS(lat, lon=lon, verbose=True)
print(ans)
# Out:
# Начало обработки точки:	56.728766, 60.587326	- Done
# {'aspect': 0, 'elevation': 260, 'hillshade': 180, 'slope': 1}

# %%
from services.terrain_GEE_USGS import terrain_GEE_USGS

# Текст для батча

coords = [
    [56.728766, 60.587326],
    [55.7558, 37.6173], # Москва
    [59.9343, 30.3351], # Санкт-Петербург
]

# Cписок Feature, меняя местами lat и lon -> [lon, lat]
features = [ee.Feature(ee.Geometry.Point([lon, lat])) for lat, lon in coords]

fc = ee.FeatureCollection(features)

ans = terrain_GEE_USGS(fc)
print(ans)
# Out:
# [{'aspect': 0, 'elevation': 260, 'hillshade': 180, 'slope': 1}, {'aspect': 79, 'elevation': 153, 'hillshade': 150, 'slope': 10}, {'aspect': 338, 'elevation': 17, 'hillshade': 186, 'slope': 5}]

# %%
data = [{'aspect': 0, 'elevation': 260, 'hillshade': 180, 'slope': 1}, {'aspect': 79, 'elevation': 153, 'hillshade': 150, 'slope': 10}, {'aspect': 338, 'elevation': 17, 'hillshade': 186, 'slope': 5}]
for i in data:
    print(i)


from services.terrain_GEE_USGS import change_key_name
for i in change_key_name(data):
    print(i)
# Out:
# {'aspect': 0, 'elevation': 260, 'hillshade': 180, 'slope': 1}
# {'aspect': 79, 'elevation': 153, 'hillshade': 150, 'slope': 10}
# {'aspect': 338, 'elevation': 17, 'hillshade': 186, 'slope': 5}
# {'aspect_GEE_USGS_30m': 0, 'elevation_GEE_USGS_30m': 260, 'hillshade_GEE_USGS_30m': 180, 'slope_GEE_USGS_30m': 1}
# {'aspect_GEE_USGS_30m': 79, 'elevation_GEE_USGS_30m': 153, 'hillshade_GEE_USGS_30m': 150, 'slope_GEE_USGS_30m': 10}
# {'aspect_GEE_USGS_30m': 338, 'elevation_GEE_USGS_30m': 17, 'hillshade_GEE_USGS_30m': 186, 'slope_GEE_USGS_30m': 5}

# %%
mapping = {'aspect': 'aspect_GEE_USGS_',
                 'elevation': 'elevation_GEE_USGS_',
                 'hillshade': 'hillshade_GEE_USGS_',
                 'slope': 'slope_GEE_USGS_'}
scale = 30

for key in mapping.keys():
    mapping[key] = mapping[key] + f"{scale}m"
# Out:
# aspect_GEE_USGS_
# elevation_GEE_USGS_
# hillshade_GEE_USGS_
# slope_GEE_USGS_
